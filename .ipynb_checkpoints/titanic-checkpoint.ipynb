# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import pandas as pd
from IPython.display import clear_output
import tensorflow.compat.v2.feature_column as fc

# %%
gpus = tf.config.experimental.list_physical_devices(device_type="GPU")

# %%
print(tf.version)
# Out:
# <module 'tensorflow._api.v2.version' from 'C:\\Users\\erik6\\anaconda3\\envs\\ML\\lib\\site-packages\\tensorflow\\_api\\v2\\version\\__init__.py'>

# %%
zeros = tf.zeros([2,2,2])

# %%
reshaped_zeros = tf.reshape(zeros,-1)

# %%
reshaped_zeros
# Out:
# <tf.Tensor: shape=(8,), dtype=float32, numpy=array([0., 0., 0., 0., 0., 0., 0., 0.], dtype=float32)>

# %%
x = [1, 2, 2.5, 3, 4]
y = [1, 4, 7, 9, 15]
plt.plot(x, y,'ro')
plt.axis([0, 6, 0, 20])
# Out:
# (0.0, 6.0, 0.0, 20.0)

# %%
plt.plot(x, y, 'ro')
plt.axis([0, 6, 0, 20])
plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.show()

# %% [markdown]
# # Regression

# %%
dftrain = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv') # training data
dfeval = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/eval.csv') # testing data
y_train = dftrain.pop('survived')
y_eval = dfeval.pop('survived')

# %%
dftrain.age.hist(bins=20)
# Out:
# <AxesSubplot:>

# %%
dftrain.sex.value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
dftrain['class'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
pd.concat([dftrain, y_train], axis=1).groupby('sex').survived.mean().plot(kind='barh').set_xlabel('survive')
# Out:
# Text(0.5, 0, 'survive')

# %%
CATEGORICAL_COLUMNS = ['sex', 'n_siblings_spouses', 'parch', 'class', 'deck',
                       'embark_town', 'alone']
NUMERIC_COLUMNS = ['age', 'fare']

feature_columns = []
for feature_name in CATEGORICAL_COLUMNS:
    vocabulary = dftrain[feature_name].unique()  # gets a list of all unique values from given feature column
    feature_columns.append(tf.feature_column.categorical_column_with_vocabulary_list(feature_name, vocabulary))

# %%
for feature_name in NUMERIC_COLUMNS:
    feature_columns.append(tf.feature_column.numeric_column(feature_name, dtype=tf.float32))

print(feature_columns)
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0), VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0), NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='fare', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
feature_columns
# Out:
# [VocabularyListCategoricalColumn(key='sex', vocabulary_list=('male', 'female'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='n_siblings_spouses', vocabulary_list=(1, 0, 3, 4, 2, 5, 8), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='parch', vocabulary_list=(0, 1, 2, 5, 3, 4), dtype=tf.int64, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='class', vocabulary_list=('Third', 'First', 'Second'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='deck', vocabulary_list=('unknown', 'C', 'G', 'A', 'B', 'D', 'F', 'E'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='embark_town', vocabulary_list=('Southampton', 'Cherbourg', 'Queenstown', 'unknown'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  VocabularyListCategoricalColumn(key='alone', vocabulary_list=('n', 'y'), dtype=tf.string, default_value=-1, num_oov_buckets=0),
#  NumericColumn(key='age', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='fare', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
def make_input_fn(data_df, label_df, num_epochs=10, shuffle=True, batch_size=32):
    def input_function():  # inner function, this will be returned
        ds = tf.data.Dataset.from_tensor_slices((dict(data_df), label_df))  # create tf.data.Dataset object with data and its label
        if shuffle:
            ds = ds.shuffle(1000)  # randomize order of data
        ds = ds.batch(batch_size).repeat(num_epochs)  # split dataset into batches of 32 and repeat process for number of epochs
        return ds  # return a batch of the dataset
    return input_function  # return a function object for use

train_input_fn = make_input_fn(dftrain, y_train)  # here we will call the input_function that was returned to us to get a dataset object we can feed to the model
eval_input_fn = make_input_fn(dfeval, y_eval, num_epochs=1, shuffle=False)

# %%
train_input_fn
# Out:
# <function __main__.make_input_fn.<locals>.input_function()>

# %%
linear_est = tf.estimator.LinearClassifier(feature_columns=feature_columns)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\erik6\AppData\Local\Temp\tmph3y43n1j
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\erik6\\AppData\\Local\\Temp\\tmph3y43n1j', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
linear_est.train(train_input_fn)  # train
result = linear_est.evaluate(eval_input_fn)  # get model metrics/stats by testing on tetsing data

clear_output()  # clears consoke output
print(result['accuracy'])  # the result variable is simply a dict of stats about our model
# Out:
# 0.75757575

# %%
result
# Out:
# {'accuracy': 0.7386364,
#  'accuracy_baseline': 0.625,
#  'auc': 0.81665146,
#  'auc_precision_recall': 0.7368819,
#  'average_loss': 0.5764174,
#  'label/mean': 0.375,
#  'loss': 0.578251,
#  'precision': 0.6171875,
#  'prediction/mean': 0.4869821,
#  'recall': 0.7979798,
#  'global_step': 200}

# %%
pred_dicts = list(linear_est.predict(eval_input_fn))
probs = pd.Series([pred['probabilities'][1] for pred in pred_dicts])

probs.plot(kind='hist', bins=20, title='predicted probabilities')
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\erik6\AppData\Local\Temp\tmph3y43n1j\model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# <AxesSubplot:title={'center':'predicted probabilities'}, ylabel='Frequency'>

# %% [markdown]
# # Classification

# %%
train_path = tf.keras.utils.get_file(
    "iris_training.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_training.csv")
test_path = tf.keras.utils.get_file(
    "iris_test.csv", "https://storage.googleapis.com/download.tensorflow.org/data/iris_test.csv")

# %%
CSV_COLUMN_NAMES = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
SPECIES = ['Setosa', 'Versicolor', 'Virginica']

# %%
train = pd.read_csv(train_path, names=CSV_COLUMN_NAMES, header=0)
test = pd.read_csv(test_path, names=CSV_COLUMN_NAMES, header=0)

# %%
train_y = train.pop('Species')
test_y = test.pop('Species')
train.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth
# 0          6.4         2.8          5.6         2.2
# 1          5.0         2.3          3.3         1.0
# 2          4.9         2.5          4.5         1.7
# 3          4.9         3.1          1.5         0.1
# 4          5.7         3.8          1.7         0.3

# %%
def input_fn(features, labels, training=True, batch_size=256):
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(1000).repeat()
    
    return dataset.batch(batch_size)

# %%
my_feature_columns = []
for key in train.keys():
    my_feature_columns.append(tf.feature_column.numeric_column(key=key))
print(my_feature_columns)
# Out:
# [NumericColumn(key='SepalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='SepalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalLength', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None), NumericColumn(key='PetalWidth', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
# Build a DNN with 2 hidden layers with 30 and 10 hidden nodes each.
classifier = tf.estimator.DNNClassifier(
    feature_columns=my_feature_columns,
    # Two hidden layers of 30 and 10 nodes respectively.
    hidden_units=[30, 10],
    # The model must choose between 3 classes.
    n_classes=3)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\erik6\AppData\Local\Temp\tmpt809jd5t
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\erik6\\AppData\\Local\\Temp\\tmpt809jd5t', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
classifier.train(
    input_fn=lambda: input_fn(train, train_y, training=True),
    steps=5000)
# We include a lambda to avoid creating an inner function previously
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From C:\Users\erik6\anaconda3\envs\ML\lib\site-packages\keras\optimizer_v2\adagrad.py:83: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\erik6\AppData\Local\Temp\tmpt809jd5t\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 1.1485702, step = 0
# INFO:tensorflow:global_step/sec: 233.724
# INFO:tensorflow:loss = 0.9256074, step = 100 (0.430 sec)
# INFO:tensorflow:global_step/sec: 254.486
# INFO:tensorflow:loss = 0.83832633, step = 200 (0.391 sec)
# INFO:tensorflow:global_step/sec: 305.693
# INFO:tensorflow:loss = 0.7989322, step = 300 (0.327 sec)
# INFO:tensorflow:global_step/sec: 299.339
# INFO:tensorflow:loss = 0.7553631, step = 400 (0.334 sec)
# INFO:tensorflow:global_step/sec: 310.917
# INFO:tensorflow:loss = 0.7339442, step = 500 (0.322 sec)
# INFO:tensorflow:global_step/sec: 306.628
# INFO:tensorflow:loss = 0.71822923, step = 600 (0.326 sec)
# INFO:tensorflow:global_step/sec: 217.5
# INFO:tensorflow:loss = 0.7019963, step = 700 (0.460 sec)
# INFO:tensorflow:global_step/sec: 322.837
# INFO:tensorflow:loss = 0.6755979, step = 800 (0.310 sec)
# INFO:tensorflow:global_step/sec: 241.312
# INFO:tensorflow:loss = 0.6630229, step = 900 (0.414 sec)
# INFO:tensorflow:global_step/sec: 356.824
# INFO:tensorflow:loss = 0.62409955, step = 1000 (0.280 sec)
# INFO:tensorflow:global_step/sec: 364.608
# INFO:tensorflow:loss = 0.6354685, step = 1100 (0.274 sec)
# INFO:tensorflow:global_step/sec: 361.977
# INFO:tensorflow:loss = 0.620061, step = 1200 (0.276 sec)
# INFO:tensorflow:global_step/sec: 263.856
# INFO:tensorflow:loss = 0.61143625, step = 1300 (0.379 sec)
# INFO:tensorflow:global_step/sec: 361.837
# INFO:tensorflow:loss = 0.59664285, step = 1400 (0.276 sec)
# INFO:tensorflow:global_step/sec: 349.363
# INFO:tensorflow:loss = 0.59367067, step = 1500 (0.286 sec)
# INFO:tensorflow:global_step/sec: 344.562
# INFO:tensorflow:loss = 0.57839245, step = 1600 (0.290 sec)
# INFO:tensorflow:global_step/sec: 326.604
# INFO:tensorflow:loss = 0.5693433, step = 1700 (0.306 sec)
# INFO:tensorflow:global_step/sec: 330.784
# INFO:tensorflow:loss = 0.568468, step = 1800 (0.302 sec)
# INFO:tensorflow:global_step/sec: 317.342
# INFO:tensorflow:loss = 0.5519583, step = 1900 (0.315 sec)
# INFO:tensorflow:global_step/sec: 208.237
# INFO:tensorflow:loss = 0.5492036, step = 2000 (0.480 sec)
# INFO:tensorflow:global_step/sec: 358.098
# INFO:tensorflow:loss = 0.54132175, step = 2100 (0.279 sec)
# INFO:tensorflow:global_step/sec: 344.561
# INFO:tensorflow:loss = 0.5427313, step = 2200 (0.290 sec)
# INFO:tensorflow:global_step/sec: 311.84
# INFO:tensorflow:loss = 0.5417382, step = 2300 (0.321 sec)
# INFO:tensorflow:global_step/sec: 279.552
# INFO:tensorflow:loss = 0.5266117, step = 2400 (0.358 sec)
# INFO:tensorflow:global_step/sec: 254.856
# INFO:tensorflow:loss = 0.5156356, step = 2500 (0.392 sec)
# INFO:tensorflow:global_step/sec: 268.813
# INFO:tensorflow:loss = 0.50775033, step = 2600 (0.372 sec)
# INFO:tensorflow:global_step/sec: 248.083
# INFO:tensorflow:loss = 0.50823534, step = 2700 (0.403 sec)
# INFO:tensorflow:global_step/sec: 230.217
# INFO:tensorflow:loss = 0.5118051, step = 2800 (0.434 sec)
# INFO:tensorflow:global_step/sec: 232.101
# INFO:tensorflow:loss = 0.5193229, step = 2900 (0.432 sec)
# INFO:tensorflow:global_step/sec: 249.551
# INFO:tensorflow:loss = 0.49695042, step = 3000 (0.400 sec)
# INFO:tensorflow:global_step/sec: 228.417
# INFO:tensorflow:loss = 0.4916319, step = 3100 (0.438 sec)
# INFO:tensorflow:global_step/sec: 339.888
# INFO:tensorflow:loss = 0.4712016, step = 3200 (0.295 sec)
# INFO:tensorflow:global_step/sec: 345.75
# INFO:tensorflow:loss = 0.48019657, step = 3300 (0.288 sec)
# INFO:tensorflow:global_step/sec: 333.116
# INFO:tensorflow:loss = 0.47200817, step = 3400 (0.300 sec)
# INFO:tensorflow:global_step/sec: 296.78
# INFO:tensorflow:loss = 0.49022266, step = 3500 (0.337 sec)
# INFO:tensorflow:global_step/sec: 334.225
# INFO:tensorflow:loss = 0.4694143, step = 3600 (0.299 sec)
# INFO:tensorflow:global_step/sec: 299.305
# INFO:tensorflow:loss = 0.47383407, step = 3700 (0.335 sec)
# INFO:tensorflow:global_step/sec: 284.851
# INFO:tensorflow:loss = 0.45622754, step = 3800 (0.350 sec)
# INFO:tensorflow:global_step/sec: 315.434
# INFO:tensorflow:loss = 0.4608754, step = 3900 (0.317 sec)
# INFO:tensorflow:global_step/sec: 305.139
# INFO:tensorflow:loss = 0.45773357, step = 4000 (0.328 sec)
# INFO:tensorflow:global_step/sec: 310.425
# INFO:tensorflow:loss = 0.43796605, step = 4100 (0.322 sec)
# INFO:tensorflow:global_step/sec: 289.791
# INFO:tensorflow:loss = 0.44980538, step = 4200 (0.345 sec)
# INFO:tensorflow:global_step/sec: 293.587
# INFO:tensorflow:loss = 0.4307852, step = 4300 (0.341 sec)
# INFO:tensorflow:global_step/sec: 275.795
# INFO:tensorflow:loss = 0.43304724, step = 4400 (0.363 sec)
# INFO:tensorflow:global_step/sec: 287.599
# INFO:tensorflow:loss = 0.43955272, step = 4500 (0.348 sec)
# INFO:tensorflow:global_step/sec: 360.674
# INFO:tensorflow:loss = 0.45199534, step = 4600 (0.277 sec)
# INFO:tensorflow:global_step/sec: 338.742
# INFO:tensorflow:loss = 0.43049926, step = 4700 (0.295 sec)
# INFO:tensorflow:global_step/sec: 354.177
# INFO:tensorflow:loss = 0.42232606, step = 4800 (0.282 sec)
# INFO:tensorflow:global_step/sec: 294.795
# INFO:tensorflow:loss = 0.42233488, step = 4900 (0.339 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into C:\Users\erik6\AppData\Local\Temp\tmpt809jd5t\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Loss for final step: 0.4083661.

# %%
eval_result = classifier.evaluate(
    input_fn=lambda: input_fn(test, test_y, training=False))
print('\nTest set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-02-21T18:48:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\erik6\AppData\Local\Temp\tmpt809jd5t\model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.19646s
# INFO:tensorflow:Finished evaluation at 2022-02-21-18:48:45
# INFO:tensorflow:Saving dict for global step 5000: accuracy = 0.76666665, average_loss = 0.5066572, global_step = 5000, loss = 0.5066572
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: C:\Users\erik6\AppData\Local\Temp\tmpt809jd5t\model.ckpt-5000
#
# Test set accuracy: 0.767

# %%
def input_fn(features, batch_size=256):
    # Convert the inputs to a Dataset without labels.
    return tf.data.Dataset.from_tensor_slices(dict(features)).batch(batch_size)

features = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']
predict = {}

print("Please type numeric values as prompted.")
for feature in features:
    valid = True
    while valid: 
        val = input(feature + ": ")
        if not val.isdigit(): valid = False

    predict[feature] = [float(val)]

predictions = classifier.predict(input_fn=lambda: input_fn(predict))
for pred_dict in predictions:
    class_id = pred_dict['class_ids'][0]
    probability = pred_dict['probabilities'][class_id]

    print('Prediction is "{}" ({:.1f}%)'.format(
        SPECIES[class_id], 100 * probability))
